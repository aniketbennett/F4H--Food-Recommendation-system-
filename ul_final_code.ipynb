# %%
def calculate_bmr(weight, height, age, gender):
    if gender == 'male':
        bmr = 10 * weight + 6.25 * height - 5 * age + 5
    elif gender == 'female':
        bmr = 10 * weight + 6.25 * height - 5 * age - 161
    else:
        print('Invalid gender')
        return None
    return bmr


def calculate_calories(bmr, activity_level):
    if activity_level == 'sedentary':
        pal = 1.2
    elif activity_level == 'lightly active':
        pal = 1.375
    elif activity_level == 'moderately active':
        pal = 1.55
    elif activity_level == 'very active':
        pal = 1.725
    elif activity_level == 'extra active':
        pal = 1.9
    else:
        print('Invalid activity level')
        return None
    calories = bmr * pal
    return calories


weight = float(input('Enter your weight in kilograms: '))
height = float(input('Enter your height in centimeters: '))
age = int(input('Enter your age: '))
gender = input('Enter your gender (male/female): ')

bmr = calculate_bmr(weight, height, age, gender)
if bmr is not None:
    print(f'Your basal metabolic rate is: {bmr:.2f} calories')

print('Select your activity level:')
print('1. Sedentary (little or no exercise)')
print('2. Lightly active (light exercise/sports 1-3 days/week)')
print('3. Moderately active (moderate exercise/sports 3-5 days/week)')
print('4. Very active (hard exercise/sports 6-7 days/week)')
print('5. Extra active (very hard exercise/sports or physical job)')
level = int(input())

if level == 1:
    activity_level = 'sedentary'
elif level == 2:
    activity_level = 'lightly active'
elif level == 3:
    activity_level = 'moderately active'
elif level == 4:
    activity_level = 'very active'
elif level == 5:
    activity_level = 'extra active'
else:
    print('Invalid activity level')
    activity_level = None

if activity_level is not None:
    calories = calculate_calories(bmr, activity_level)
    if calories is not None:
        print(f'Your daily calorie requirement is: {calories:.2f} calories')
# Out:
# Enter your weight in kilograms: 85
# Enter your height in centimeters: 177
# Enter your age: 22
# Enter your gender (male/female): male
# Your basal metabolic rate is: 1851.25 calories
# Select your activity level:
# 1. Sedentary (little or no exercise)
# 2. Lightly active (light exercise/sports 1-3 days/week)
# 3. Moderately active (moderate exercise/sports 3-5 days/week)
# 4. Very active (hard exercise/sports 6-7 days/week)
# 5. Extra active (very hard exercise/sports or physical job)
# 4
# Your daily calorie requirement is: 3193.41 calories

# %%
import pandas as pd

# read demo_6.csv file
df1 = pd.read_csv('final_diseases.csv')

# read demo_7.csv file
df2 = pd.read_csv('final_food_items.csv')

pre_meal = input("Do you prefer Vegetarian or Non-vegetarian meal ?: ")

num_diseases = int(input("How many diseases are you suffering from? "))

diseases = []
for i in range(num_diseases):
    disease = input("Enter the name of disease #" + str(i+1) + ": ")
    diseases.append(disease)

# find nutritional component values for entered diseases in demo_6.csv
nutritional_components = []
for disease in diseases:
    row = df1.loc[df1['Disease'] == disease]
    nutritional_components.append(list(row.iloc[:, 1:].values[0]))

# create a list that contains the final daily intake of each nutritional component for all diseases
final_list = nutritional_components[0]
for components in nutritional_components[1:]:
    for i, value in enumerate(components):
        final_list[i] = min(final_list[i], value)

# create a dictionary to store food items for each nutritional component
food_items_dict = {}

# iterate over each nutritional component in the final_list
for i, component_value in enumerate(final_list):
    
    # get the name of the nutritional component
    component_name = df2.columns[i+1]
    
    # create an empty list to store food items for this nutritional component
    food_items = []
    
    # iterate over each row in demo_7.csv
    for index, row in df2.iterrows():
        
        # get the value of the current nutritional component for this food item
        food_component_value = row[component_name]
        
        # check if the nutritional component value for this food item is within 90% of the required daily intake
        if abs(float(food_component_value) - float(component_value)) / float(component_value) <= 0.90:
            
            # add this food item to the list
            food_items.append(row['food items'])
    
    # add the list of food items for this nutritional component to the dictionary
    food_items_dict[component_name] = food_items

food_i_list = list(food_items_dict.values())
food_i_list = sum(food_i_list, [])
unique_list = list(set(food_i_list))
print(final_list)
print(unique_list)
# Out:
# Do you prefer Vegetarian or Non-vegetarian meal ?: Vegetarian
# How many diseases are you suffering from? 3
# Enter the name of disease #1: Coeliac disease
# Enter the name of disease #2: Trigger Finger
# Enter the name of disease #3: Sore Throat
# [247.5, 60.0, 14.66, 56.0, 25.0, 200.0, 1500.0, 25.0, 3400.0, 358.0, 700.0, 80.0, 800.0, 1100.0, 8.0, 10.0, 15.0, 120.0]
# ['Cacao Seeds', 'Pearled Barley', 'hot choclate', 'Almond Milkshake', 'Pine Nuts', 'Uglifruit', 'Black Barley', 'Aloo Toast Sandwich', 'Brown Rice', 'Fish chowder soup', 'egg sandwich', 'Coconut', 'Gazpacho soup', 'Capsicum', 'Kidney Bean', 'paneer sandwich', 'Barnyard Millets', 'Brown Teff', 'Pearl Millet', 'Yuca Root', 'buffalo milk', 'Smoothies', 'Acorn', "Sheep's Milk", 'Jojoto', 'Wild Rices', 'Cedar Nuts', "sheep's milk", 'white hot chocolate', 'Carrot Juice', 'Squash Seeds', 'Cranberry', 'Heartnut', 'Whole Milk', 'Cabbage', 'baru Nuts', 'Chia Seed', 'Chai Latte(iced)', 'Jackfruit Seed', 'Golden milk', 'Daikon Radish', 'Little Millet', 'Bread Butter Sandwich', 'beech Nuts', 'Hispi Cabbage', 'Navy Beans', 'Hazelnuts', 'Chicken Caesar salad', 'skim milk', 'Espresso', 'Kodo Millet', 'Italian pasta salad', 'Mongongo Nuts', 'Spelt', 'Almonds', 'Starfruit', 'Cochin Chicken', 'Crabs Fish', 'Barnyard Millet', 'Acorns', 'Zebra Eggplant', 'Skim Milk', 'Rosa Bianca Eggplant', 'Pomfret Fish', 'Peas', 'Heavy cream', 'Normal Milk', 'Jam Sandwich', 'Bone broth', 'quinoa seeds', 'Pumpernickel', 'Italian Red Onion', 'Paratha', 'Iceberg Lettuce', 'Land Cress', 'Israeli salad', 'Coleslaw Sandwich', 'Basmati Rice', 'Courgette', 'Popcorn', 'Einkorn Wheat', 'Steak salad', 'Blueberries', 'Rabbits Meat', 'Rhubarb', 'Broccoli', 'Desi Ghee', 'Hot Chocolate', 'Citrus avocado salad', 'Cucumber Water', 'Longan Fruit', 'New Potatoes', 'Dalgona coffee', 'Kohlrabi', 'Silverhull Buckwheat', 'Beef stew soup', 'Mango and black bean salad', 'Quinoa salad', 'Peach and burrata salad', 'Pearl Millets', 'Persimmon', 'Cime de Rapa', 'Cranberry Juice', 'vegie delight sandwich', 'Yellow Onion', 'Beetroot Juice', 'Hemp Seeds', 'Egg salad', 'Pomegranate', 'Surmai Fish', 'Chickpea salad', 'greek gogurt', 'Strawberry Juice', 'Summer corn salad', 'Durian', 'Guava', 'Red Rice', 'Black Rice', 'Lentil salad', 'Broccoli cheddar soup', 'Masala chai', 'Molokhia', 'Bangda Fish', 'Blueberry Smoothies', 'Yam Bean', 'Chayote Squash', 'Sour Cream', 'Tomato soup', 'Potato', 'Broad Beans', 'Coconut hot chocolate', 'Horchata', 'Oak Nuts', 'Lobster Fish', 'Fiddlehead', 'Cantaloupe', 'Paneer Sandwich', 'Filbert', 'Macadamia Nuts', 'Tabouli salad', 'Escarole', 'Watermelon and feta salad', 'Kennebec Potato', 'whole milk', 'Fruit salad', 'Tri-color Quinoa', 'Greek Yogurt', 'Onion', 'Unsalted Butter', 'Lemon ginger tea', 'Yao Choy', 'Hulled Barley', 'Heirloom Tomatoes', 'black Walnut', 'Plum Tomatoes', 'Goat Ghee', 'Emmer Farro', 'Chestnuts', 'Caesar salad with shrimp', 'Cold-pressed Juice', 'Coleslaw', 'Tea with milk and sugar', 'Kale salad', 'Pork Meat', 'Leaf Celery', 'Galangal', 'Welsh Onions', 'Split pea soup', 'Orange', 'squash seeds', 'Katla Fish', 'Arnold Palmer', 'Red potato salad with dill', 'Roma Tomatoes', 'Wild RIce', 'Beet and goat cheese salad', 'Mint Lemonande', 'Walnuts', 'Water Chestnut', 'Coffee with cream and sugar', 'Emu Meat', 'Foxtail Millets', 'Irish coffee', 'kidney beans', 'Dickinson Pumpkin', 'Soynuts', 'White Quinoa', 'Turkey Meat', 'Lacinto Kale', 'Sweet Corn', 'Calabrese', 'Mango Juice', 'Harrd Red Wheat', 'Heartnuts', 'Slushies', 'Chocolate Milkshake', 'Butternut Squash', 'Pomegranate Juice', 'Bun Bread', 'Cream Cheese', 'Zucchini', 'Tangerine', 'Shrimp Seafood', 'Cardamom coffee', 'Lagos Bologi', 'Flavored Water', 'Pineapple', 'Buckwheat Groats', 'Papaya Juice', 'Frappuccino', 'Black Coffee', 'Chicken and Dumpling Soup', 'pinto\xa0beans', 'Sesame Seed', 'Plum', 'Japanese Mustard Greens', 'Cow Ghee', 'Mulled Wine', 'Bissap', 'Grapefruit Juice', 'Delicata Squash', 'Roasted beet salad', 'Fingerlimes', 'Lychee', 'Pumpkin', 'Emmer Wheat', 'High-altitude Quinoa', 'Spinach', 'White Radish', 'Brazil nut', 'Eggplant', 'Borscht Soup', 'ghee', 'Tengra Fish', 'Nectarines', 'chicken sandwich', 'Steel-cut Oatss', 'cheese sandwich', 'veg grilled sandwich', 'navy beans\xa0', 'Almond', 'Flint Corn', 'Barley Gritss', 'Black Bean Soup', 'Rooibos Iced tea', 'cottage cheese', ' ...

# %%
original_calories = 2200
adjusted_list = []
for value in final_list:
    adjusted_value = value * (calories / original_calories)
    adjusted_list.append(round(adjusted_value, 2))

print(adjusted_list)
# Out:
# [359.26, 87.09, 21.28, 81.29, 36.29, 290.31, 2177.32, 36.29, 4935.26, 519.65, 1016.08, 116.12, 1161.24, 1596.7, 11.61, 14.52, 21.77, 174.19]

# %%
import pandas as pd
from termcolor import colored
# read the Calorie_value.csv file
df = pd.read_csv('Calorie_value.csv')

# %%
if (pre_meal == 'Vegetarian'):
    meal_categories = {
    'Breakfast': ('Breakfast grains', 'Fruits', 'Vegetables', 'Protien', 'Healthy Fats','Breads','Juice','Indian bread','Tea & Coffee'),
    'Lunch': ('Grains', 'Indian bread', 'Vegetables', 'Salads', 'Healthy Fats','Soup','Dairy'),
    'Snacks': ('Tea & Coffee','Sandwich','Nuts & Seeds','Fruits','Beverages','Juice'),
    'Dinner': ('Grains', 'Indian bread', 'Vegetables', 'Salads', 'Healthy Fats','Soup','Dairy')
    }

    # create a dictionary to store food items for each category
    food_items_by_category = {category: [] for category in meal_categories.values()}

    for food_item in unique_list:

        # get the category of the current food item
        category = df.loc[df['food items'] == food_item, 'Category'].values[0]

        # add the food item to the list for the category
        for meal_category, categories in meal_categories.items():
            if category in categories:
                food_items_by_category.setdefault(meal_category + ': ' + category, []).append(food_item)

    # print the list of food items for each meal category and category
    for meal_category, categories in meal_categories.items():
        print(colored(meal_category.title(), 'blue', attrs=['bold']))
        for category in categories:
            key = meal_category + ': ' + category
            if key in food_items_by_category and food_items_by_category[key]:
                print('   ' + category + ': ' + ', '.join(food_items_by_category[key]))
                
elif(pre_meal == 'Non-vegetarian'):
    meal_categories = {
    'Breakfast': ('Breakfast grains', 'Fruits', 'Vegetables','Non-veg Protien','Protien', 'Healthy Fats','Breads','Juice','Indian bread','Tea & Coffee'),
    'Lunch': ('Grains', 'Indian bread', 'Vegetables', 'Salads', 'Healthy Fats','Soup','Dairy','Meat', 'Non-veg Salads','Non-veg Soup'),
    'Snacks': ('Tea & Coffee','Sandwich','Nuts & Seeds','Fruits','Beverages','Juice','Non-veg Sandwich'),
    'Dinner': ('Grains', 'Indian bread', 'Vegetables', 'Salads', 'Healthy Fats','Soup','Dairy','Meat','Non-veg Salads','Non-veg Soup')
    }

    # create a dictionary to store food items for each category
    food_items_by_category = {category: [] for category in meal_categories.values()}

    for food_item in unique_list:

        # get the category of the current food item
        category = df.loc[df['food items'] == food_item, 'Category'].values[0]

        # add the food item to the list for the category
        for meal_category, categories in meal_categories.items():
            if category in categories:
                food_items_by_category.setdefault(meal_category + ': ' + category, []).append(food_item)

    # print the list of food items for each meal category and category
    for meal_category, categories in meal_categories.items():
        print(colored(meal_category.title(), 'blue', attrs=['bold']))
        for category in categories:
            key = meal_category + ': ' + category
            if key in food_items_by_category and food_items_by_category[key]:
                print('   ' + category + ': ' + ', '.join(food_items_by_category[key]))
# Out:
# Breakfast
#    Breakfast grains: Barnyard Millets, Wild Rices, Pearl Millets, Foxtail Millets, Steel-cut Oatss, Barley Gritss, Whole Grain Wheat, Little Millets, Whole Barleys, Sorghum Flakes, Whole Grain Quinoa, Basmati Rices, Kodo Millets, Brown Rices, Barley Flakess, Sweet Corns, Whole grain Sorghum, White Sorghums, Whole Ryes, Quick Oatss, Instant Oatss, Oat Groatss, Rolled Oatss
#    Fruits: Uglifruit, Cranberry, Starfruit, Blueberries, Rhubarb, Longan Fruit, Persimmon, Pomegranate, Durian, Guava, Cantaloupe, Orange, Tangerine, Pineapple, Plum, Lychee, Nectarines, Watermelon, Grapefruit, Gooseberries, Golden berries, Blackberries, Redberries, Cherry, Papaya, Black Chokeberry, Apricot, Jackfruit, Apple, Jujube, Avocado, Strawberry, Grapes, Pomelo, Date Palm, Kiwi, Passion Fruit, Raspberry, Banana, Melon, Mulberry, Mango, Rambutan, Juniper Berries, Elderberry, Pear
